# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\User\Downloads\world_population.csv")
df
# Out:
#      Rank CCA3  Country/Territory           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
df[df['Rank']<=5]
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 41      1  CHN             China           Beijing           Asia
# 92      2  IND             India         New Delhi           Asia
# 93      4  IDN         Indonesia           Jakarta           Asia
# 156     5  PAK          Pakistan         Islamabad           Asia
# 221     3  USA     United States  Washington, D.C.  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41        1425887337       1424929781       1393715448       1348191368
# 92        1417173173       1396387127       1322866505       1240613620
# 93         275501339        271857970        259091970        244016173
# 156        235824862        227196741        210969298        194454498
# 221        338289857        335942003        324607776        311182845
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# ...

# %%
specific_countries=['Kenya','Uganda']
df[df['Country/Territory'].isin(specific_countries)]
# Out:
#      Rank CCA3 Country/Territory  Capital Continent  2022 Population  \
# 106    27  KEN             Kenya  Nairobi    Africa         54027487
# 217    31  UGA            Uganda  Kampala    Africa         47249585
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 106         51985780         46851488         41517895         30851606
# 217         44404611         37477356         32341728         24020697
#
#      1990 Population  1980 Population  1970 Population  Area (km²)  \
# 106         23162269         16187124         11473087      580367
# 217         17586630         13284026         10317212      241550
#
#      Density (per km²)  Growth Rate  World Population Percentage
# 106            93.0919       1.0193                         0.68
# 217           195.6100       1.0304                         0.59

# %%
df[df['Country/Territory'].str.contains('United')]
# Out:
#      Rank CCA3             Country/Territory           Capital      Continent  \
# 219    97  ARE          United Arab Emirates         Abu Dhabi           Asia
# 220    21  GBR                United Kingdom            London         Europe
# 221     3  USA                 United States  Washington, D.C.  North America
# 222   200  VIR  United States Virgin Islands  Charlotte Amalie  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 219          9441129          9287289          8916899          8481771
# 220         67508936         67059474         65224364         62760039
# 221        338289857        335942003        324607776        311182845
# 222            99465           100442           102803           106142
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 219          3275333          1900151          1014048           298084
# ...

# %%
df2=df.set_index('Country/Territory')
df2
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country/Territory
# Afghanistan          36  AFG             Kabul      Asia         41128771
# Albania             138  ALB            Tirana    Europe          2842321
# Algeria              34  DZA           Algiers    Africa         44903225
# American Samoa      213  ASM         Pago Pago   Oceania            44273
# Andorra             203  AND  Andorra la Vella    Europe            79824
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania            11572
# Western Sahara      172  ESH          El Aaiún    Africa           575986
# Yemen                46  YEM             Sanaa      Asia         33696614
# Zambia               63  ZMB            Lusaka    Africa         20017675
# Zimbabwe             74  ZWE            Harare    Africa         16320537
#
# ...

# %%
df2.filter(items=['Continent','CCA3'], axis=1)
# Out:
#                   Continent CCA3
# Country/Territory
# Afghanistan            Asia  AFG
# Albania              Europe  ALB
# Algeria              Africa  DZA
# American Samoa      Oceania  ASM
# Andorra              Europe  AND
# ...                     ...  ...
# Wallis and Futuna   Oceania  WLF
# Western Sahara       Africa  ESH
# Yemen                  Asia  YEM
# Zambia               Africa  ZMB
# Zimbabwe             Africa  ZWE
#
# [234 rows x 2 columns]

# %%
df2.filter(items=['Kenya'], axis=0)
# Out:
#                    Rank CCA3  Capital Continent  2022 Population  \
# Country/Territory
# Kenya                27  KEN  Nairobi    Africa         54027487
#
#                    2020 Population  2015 Population  2010 Population  \
# Country/Territory
# Kenya                     51985780         46851488         41517895
#
#                    2000 Population  1990 Population  1980 Population  \
# Country/Territory
# Kenya                     30851606         23162269         16187124
#
#                    1970 Population  Area (km²)  Density (per km²)  \
# Country/Territory
# Kenya                     11473087      580367            93.0919
#
#                    Growth Rate  World Population Percentage
# Country/Territory
# Kenya                   1.0193                         0.68

# %%
df2.filter(like = 'Island', axis = 0)
# Out:
#                               Rank CCA3           Capital      Continent  \
# Country/Territory
# British Virgin Islands         221  VGB         Road Town  North America
# Cayman Islands                 205  CYM       George Town  North America
# Cook Islands                   223  COK            Avarua        Oceania
# Falkland Islands               231  FLK           Stanley  South America
# Faroe Islands                  209  FRO          Tórshavn         Europe
# Marshall Islands               215  MHL            Majuro        Oceania
# Northern Mariana Islands       210  NFK            Saipan        Oceania
# Solomon Islands                166  SLB           Honiara        Oceania
# Turks and Caicos Islands       212  TCA     Cockburn Town  North America
# United States Virgin Islands   200  VIR  Charlotte Amalie  North America
#
#                               2022 Population  2020 Population  \
# Country/Territory
# ...

# %%
df2.loc['United States']
# Out:
# Rank                                          3
# CCA3                                        USA
# Capital                        Washington, D.C.
# Continent                         North America
# 2022 Population                       338289857
# 2020 Population                       335942003
# 2015 Population                       324607776
# 2010 Population                       311182845
# 2000 Population                       282398554
# 1990 Population                       248083732
# 1980 Population                       223140018
# 1970 Population                       200328340
# Area (km²)                              9372610
# Density (per km²)                       36.0935
# Growth Rate                              1.0038
# World Population Percentage                4.24
# Name: United States, dtype: object

# %%
df2.iloc[106]
# Out:
# Rank                                 27
# CCA3                                KEN
# Capital                         Nairobi
# Continent                        Africa
# 2022 Population                54027487
# 2020 Population                51985780
# 2015 Population                46851488
# 2010 Population                41517895
# 2000 Population                30851606
# 1990 Population                23162269
# 1980 Population                16187124
# 1970 Population                11473087
# Area (km²)                       580367
# Density (per km²)               93.0919
# Growth Rate                      1.0193
# World Population Percentage        0.68
# Name: Kenya, dtype: object

# %%
df[df['Rank']<10].sort_values(by=['Continent','Country/Territory'],ascending=False)
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 27      7  BRA            Brazil          Brasilia  South America
# 221     3  USA     United States  Washington, D.C.  North America
# 171     9  RUS            Russia            Moscow         Europe
# 156     5  PAK          Pakistan         Islamabad           Asia
# 93      4  IDN         Indonesia           Jakarta           Asia
# 92      2  IND             India         New Delhi           Asia
# 41      1  CHN             China           Beijing           Asia
# 16      8  BGD        Bangladesh             Dhaka           Asia
# 149     6  NGA           Nigeria             Abuja         Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 27         215313498        213196304        205188205        196353492
# 221        338289857        335942003        324607776        311182845
# 171        144713314        145617329        144668389        143242599
# ...
