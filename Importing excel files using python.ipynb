# %%
#Importing library

# %%
import pandas as pd

# %%
#Read csv files

# %%
df=pd.read_csv(r"C:\Users\User\Desktop\hotel_revenue_2019.csv")
df
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            1         20               2019
# 1      Resort Hotel            1         76               2019
# 2      Resort Hotel            1        113               2019
# 3      Resort Hotel            1        113               2019
# 4      Resort Hotel            1        113               2019
# ...             ...          ...        ...                ...
# 79259  Resort Hotel            1         61               2019
# 79260  Resort Hotel            1        219               2019
# 79261  Resort Hotel            1        219               2019
# 79262  Resort Hotel            1        219               2019
# 79263  Resort Hotel            1        118               2019
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                January                         1                          1
# ...

# %%
#check for missing values

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
#Check for t=data types

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                            int64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
#change data type for reservation status date

# %%
df['reservation_status_date']=pd.to_datetime(df['reservation_status_date'])

# %%
df.dtypes
# Out:
# hotel                                     object
# is_canceled                                int64
# lead_time                                  int64
# arrival_date_year                          int64
# arrival_date_month                        object
# arrival_date_week_number                   int64
# arrival_date_day_of_month                  int64
# stays_in_weekend_nights                    int64
# stays_in_week_nights                       int64
# adults                                     int64
# children                                   int64
# babies                                     int64
# meal                                      object
# country                                   object
# market_segment                            object
# distribution_channel                      object
# is_repeated_guest                          int64
# previous_cancellations                     int64
# previous_bookings_not_canceled             int64
# ...

# %%
#DATA FRAME EXPORTS
#convert all rows into a list of tuples

# %%
y=[]
for i in range(len(df)):
    x=tuple(df.iloc[i])
    y.append(x)
y
# Out:
# [('Resort Hotel',
#   1,
#   20,
#   2019,
#   'January',
#   1,
#   1,
#   0,
#   2,
#   2,
#   2,
#   0,
#   'BB',
#   'PRT',
#   'Online TA',
#   'TA/TO',
#   0,
#   0,
#   0,
#   'G',
#   'G',
#   0,
#   'No Deposit',
#   240,
#   0,
#   0,
#   'Transient',
#   119.0,
#   0,
#   0,
#   'Canceled',
#   Timestamp('2018-12-22 00:00:00')),
#  ('Resort Hotel',
#   1,
#   76,
#   2019,
#   'January',
#   1,
#   1,
#   1,
#   2,
#   2,
#   0,
#   0,
#   'BB',
#   'PRT',
#   'Online TA',
#   'TA/TO',
#   0,
#   0,
#   0,
#   'A',
#   'A',
#   0,
#   'No Deposit',
#   240,
#   0,
#   0,
#   'Transient',
#   57.9,
#   0,
#   1,
#   'Canceled',
#   Timestamp('2018-12-20 00:00:00')),
#  ('Resort Hotel',
#   1,
#   113,
#   2019,
#   'January',
#   1,
#   2,
#   0,
#   1,
#   2,
#   0,
#   0,
#   'HB',
#   'PRT',
#   'Groups',
#   'Direct',
#   0,
#   0,
#   0,
#   'A',
#   'A',
#   0,
#   'Non Refund',
#   305,
#   0,
#   0,
#   'Transient',
#   72.0,
#   0,
#   0,
#   'Canceled',
# ...

# %%
#Save lisst as txt file

# %%
file=open('hotel_revenue_2019.txt', 'w',)
for tuple in y:
    file.write(str(tuple)+ ',' + '\n')
    
file.close()

# %%
os.getcwd ()
# Out:
# 'C:\\Users\\User'
